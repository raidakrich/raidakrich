# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Requirement already satisfied: pygit2==1.15.1 in /usr/local/lib/python3.12/dist-packages (1.15.1)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pygit2==1.15.1) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (3.0)
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 14913 MB, total RAM 12976 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# /usr/local/lib/python3.12/dist-packages/numba/__init__.py:48: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.4.3)
#   import scipy
# Using pytorch cross attention
# /content/Fooocus/ldm_patched/unipc/uni_pc.py:56: SyntaxWarning: invalid escape sequence '\h'
#   The `alphas_cumprod` is the \hat{alpha_n} arrays in the notations of DDPM. Specifically, DDPMs assume that
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# model_type EPS
# UNet ADM Dimension 2816
# Running on public URL: https://6ece69ad8841f2ed8d.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_l.text_projection'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.73 seconds
# 2026-03-16 01:24:47.398258: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773624287.651719    8999 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773624287.720518    8999 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773624288.251698    8999 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773624288.251746    8999 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773624288.251751    8999 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773624288.251769    8999 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-16 01:24:48.301032: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 8667
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://6ece69ad8841f2ed8d.gradio.live
# Loaded preset: /content/Fooocus/presets/realistic.json
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticStockPhoto_v20.safetensors" to /content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors
#
#  19% 1.25G/6.46G [00:13<00:28, 195MB/s]ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/uvicorn/protocols/websockets/websockets_impl.py", line 244, in run_asgi
#     result = await self.app(self.scope, self.asgi_receive, self.asgi_send)  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/applications.py", line 1160, in __call__
#     await super().__call__(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/middleware/errors.py", line 151, in __call__
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/middleware/cors.py", line 79, in __call__
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/middleware/exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "/usr/local/lib/python3.12/dist-packages/starlette/_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/middleware/asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/routing.py", line 364, in handle
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/routing.py", line 156, in app
#     await wrap_app_handling_exceptions(app, session)(scope, receive, send)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "/usr/local/lib/python3.12/dist-packages/starlette/_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/routing.py", line 153, in app
#     await func(session)
#   File "/usr/local/lib/python3.12/dist-packages/fastapi/routing.py", line 760, in app
#     await dependant.call(**solved_result.values)
#   File "/usr/local/lib/python3.12/dist-packages/gradio/routes.py", line 604, in join_queue
#     session_info = await asyncio.wait_for(
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/starlette/websockets.py", line 136, in receive_json
#     self._raise_on_disconnect(message)
#   File "/usr/local/lib/python3.12/dist-packages/starlette/websockets.py", line 114, in _raise_on_disconnect
#     raise WebSocketDisconnect(message["code"], message.get("reason"))
# starlette.websockets.WebSocketDisconnect: (1001, '')
#  41% 2.62G/6.46G [00:31<00:31, 133MB/s][Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 5219812931856144324
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
#  45% 2.91G/6.46G [00:37<00:24, 153MB/s][Prompt Expansion] Ultra-modern, abstract digital art, smooth gradients in pink and white, soft lighting, minimalistic design, futuristic shapes floating in space, high-resolution, cinematic style, modern fine detail, very inspirational, beautiful, atmosphere, rich colors, epic composition, intricate, elegant, sharp focus, professional color, highly detailed, lucid full perfect, ambient light, dynamic dramatic
# [Fooocus] Preparing Fooocus text #2 ...
#  46% 2.97G/6.46G [00:37<00:25, 147MB/s][Prompt Expansion] Ultra-modern, abstract digital art, smooth gradients in pink and white, soft lighting, minimalistic design, futuristic shapes floating in space, high-resolution, cinematic style, highly detailed, great light, beautiful composition, clear quality, very inspirational, innocent, cute, creative, positive, artistic, vibrant, enhanced, glowing, rich deep colors, inspired, loving
# [Fooocus] Encoding positive #1 ...
#  47% 3.02G/6.46G [00:40<01:18, 46.9MB/s][Fooocus Model Management] Moving model(s) has taken 0.24 seconds
#  49% 3.15G/6.46G [00:40<00:21, 167MB/s][Fooocus] Encoding positive #2 ...
#  50% 3.20G/6.46G [00:41<00:19, 175MB/s][Fooocus] Encoding negative #1 ...
#  51% 3.30G/6.46G [00:42<00:25, 135MB/s][Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 10.12 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
#  51% 3.32G/6.46G [00:42<00:21, 160MB/s][Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
#  53% 3.40G/6.46G [00:42<00:35, 93.9MB/s]Requested to load SDXL
# Loading 1 new model
#  60% 3.85G/6.46G [00:54<00:25, 110MB/s][Fooocus Model Management] Moving model(s) has taken 8.08 seconds
#  60% 3.87G/6.46G [00:54<00:23, 119MB/s]
#  68% 4.41G/6.46G [01:05<00:45, 48.9MB/s]
#   3% 1/30 [00:11<05:23, 11.15s/it]Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1434, in process_api
#     data = self.postprocess_data(fn_index, result["prediction"], state)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1326, in postprocess_data
#     prediction_value = postprocess_update_dict(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 460, in postprocess_update_dict
#     prediction_value["value"] = block.postprocess(prediction_value["value"])
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/gradio_hijack.py", line 326, in postprocess
#     return processing_utils.encode_array_to_base64(y)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py", line 104, in encode_array_to_base64
#     pil_image = Image.fromarray(_convert(image_array, np.uint8, force_copy=False))
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py", line 260, in _convert
#     np.bool8: (False, True),  # type: ignore
#     ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/__init__.py", line 792, in __getattr__
#     raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
# AttributeError: module 'numpy' has no attribute 'bool8'. Did you mean: 'bool'?
#  71% 4.58G/6.46G [01:06<00:11, 179MB/s]
#  72% 4.67G/6.46G [01:07<00:10, 181MB/s]
#  10% 3/30 [00:13<01:27,  3.24s/it]
#  13% 4/30 [00:13<01:00,  2.31s/it]
#  17% 5/30 [00:14<00:44,  1.80s/it]
#  20% 6/30 [00:15<00:35,  1.49s/it]
#  74% 4.78G/6.46G [01:11<00:34, 51.7MB/s]
#  76% 4.91G/6.46G [01:12<00:13, 123MB/s]
#  77% 5.00G/6.46G [01:13<00:13, 119MB/s]
#  33% 10/30 [00:19<00:20,  1.03s/it]
#  37% 11/30 [00:20<00:18,  1.00it/s]
#  40% 12/30 [00:21<00:17,  1.03it/s]
#  78% 5.07G/6.46G [01:17<00:38, 38.6MB/s]
#  81% 5.23G/6.46G [01:18<00:11, 120MB/s]
#  82% 5.28G/6.46G [01:18<00:08, 144MB/s]
#  53% 16/30 [00:24<00:13,  1.06it/s]
#  57% 17/30 [00:25<00:12,  1.06it/s]
#  60% 18/30 [00:26<00:11,  1.06it/s]
#  63% 19/30 [00:27<00:10,  1.06it/s]
#  84% 5.43G/6.46G [01:24<00:10, 102MB/s]
#  86% 5.53G/6.46G [01:25<00:11, 89.3MB/s]
#  73% 22/30 [00:30<00:07,  1.05it/s]
#  77% 23/30 [00:31<00:06,  1.05it/s]
#  80% 24/30 [00:32<00:05,  1.04it/s]
#  83% 25/30 [00:33<00:04,  1.04it/s]
#  86% 5.57G/6.46G [01:29<00:42, 22.2MB/s]
#  88% 5.71G/6.46G [01:30<00:08, 95.9MB/s]
#  89% 5.75G/6.46G [01:31<00:06, 111MB/s]
#  97% 29/30 [00:37<00:00,  1.02it/s]
# 100% 30/30 [00:38<00:00,  1.28s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
#  92% 5.95G/6.46G [01:36<00:04, 129MB/s] [Fooocus] Saving image 1/2 to system ...
#  93% 6.00G/6.46G [01:37<00:03, 140MB/s]Image generated with private log at: /content/Fooocus/outputs/2026-03-16/log.html
# Generating and saving time: 55.43 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.63 seconds
#
#  93% 6.02G/6.46G [01:38<00:15, 31.6MB/s]
#  95% 6.16G/6.46G [01:40<00:02, 133MB/s]
#  96% 6.23G/6.46G [01:40<00:01, 138MB/s]
#  97% 6.25G/6.46G [01:42<00:05, 39.2MB/s]
#  97% 6.28G/6.46G [01:43<00:06, 32.4MB/s]
#  99% 6.40G/6.46G [01:44<00:00, 155MB/s]
# 100% 6.46G/6.46G [01:45<00:00, 66.1MB/s]
# Downloading: "https://huggingface.co/mashb1t/fav_models/resolve/main/fav/SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors" to /content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors
#
#   0% 0.00/870M [00:00<?, ?B/s]
#   5% 40.2M/870M [00:01<00:17, 48.7MB/s]
#  16% 140M/870M [00:02<00:06, 124MB/s]
#  30% 9/30 [00:09<00:22,  1.08s/it]
#  18% 154M/870M [00:04<00:40, 18.5MB/s]
#  33% 283M/870M [00:05<00:06, 92.1MB/s]
#  48% 415M/870M [00:06<00:03, 134MB/s]
#  43% 13/30 [00:14<00:18,  1.07s/it]
#  47% 14/30 [00:15<00:16,  1.06s/it]
#  50% 15/30 [00:16<00:15,  1.06s/it]
#  49% 428M/870M [00:10<00:38, 12.0MB/s]
#  64% 558M/870M [00:12<00:04, 70.1MB/s]
#  80% 695M/870M [00:12<00:01, 177MB/s]
#  63% 19/30 [00:20<00:11,  1.04s/it]
#  67% 20/30 [00:21<00:10,  1.03s/it]
#  70% 21/30 [00:22<00:09,  1.03s/it]
#  85% 741M/870M [00:17<00:05, 24.1MB/s]
# 100% 870M/870M [00:18<00:00, 50.6MB/s]
#
#  80% 24/30 [00:25<00:06,  1.03s/it]
#  83% 25/30 [00:26<00:05,  1.02s/it]
#  87% 26/30 [00:27<00:04,  1.02s/it]
#  90% 27/30 [00:28<00:03,  1.01s/it]
#  93% 28/30 [00:29<00:02,  1.01s/it]
#  97% 29/30 [00:30<00:01,  1.01s/it]
# 100% 30/30 [00:31<00:00,  1.05s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.25 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-03-16/log.html
# Generating and saving time: 35.35 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 90.78 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.94 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 2090714333408694406
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Futuristic neon pink logo that says "PUSHER" floating in an abstract digital landscape, glowing accents, soft focus background, cinematic, minimalistic, full color, imposing, rich deep colors, inspired, intricate, elegant, highly detailed, professional, light, colorful, epic, great grand lucid, peaceful, artistic, pure, loving, beautiful, rational, scenic
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Futuristic neon pink logo that says "PUSHER" floating in an abstract digital landscape, glowing accents, soft focus background, cinematic, minimalistic, epic, magical atmosphere, intricate, elegant, extremely detailed, professional illuminated, clear, artistic, pure color, complex, very complimentary colors, highly detail, ambient light, sharp, perfect composition, lush, beautiful full
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 1.79 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.22 seconds
#   3% 1/30 [00:00<00:25,  1.13it/s]Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1434, in process_api
#     data = self.postprocess_data(fn_index, result["prediction"], state)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1326, in postprocess_data
#     prediction_value = postprocess_update_dict(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 460, in postprocess_update_dict
#     prediction_value["value"] = block.postprocess(prediction_value["value"])
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/gradio_hijack.py", line 326, in postprocess
#     return processing_utils.encode_array_to_base64(y)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py", line 104, in encode_array_to_base64
#     pil_image = Image.fromarray(_convert(image_array, np.uint8, force_copy=False))
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py", line 260, in _convert
#     np.bool8: (False, True),  # type: ignore
#     ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/__init__.py", line 792, in __getattr__
#     raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
# AttributeError: module 'numpy' has no attribute 'bool8'. Did you mean: 'bool'?
# 100% 30/30 [00:28<00:00,  1.06it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-03-16/log.html
# Generating and saving time: 33.22 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.66 seconds
# 100% 30/30 [00:28<00:00,  1.04it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-03-16/log.html
# Generating and saving time: 32.47 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 65.69 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.86 seconds
# Loaded preset: /content/Fooocus/presets/realistic.json
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1097312811866960966
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Futuristic neon pink logo that says "PUSHER" floating in an abstract digital landscape, glowing accents, soft focus background, cinematic, minimalistic, epic, polished, complex, highly detailed, rich deep color, great composition, futuristic, atmosphere, dynamic light, new, amazing, creative, exciting, shiny, attractive, beautiful, elegant, luxury, brilliant
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Futuristic neon pink logo that says "PUSHER" floating in an abstract digital landscape, glowing accents, soft focus background, cinematic, minimalistic, elegant, highly detailed, intricate, sharp, aesthetic, very inspirational, deep colors, candid, extremely beautiful, tailored, rich, complex, artistic, epic, dramatic ambient, shining light, advanced, best, creative
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.14 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.25 seconds
#   0% 0/60 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1434, in process_api
#     data = self.postprocess_data(fn_index, result["prediction"], state)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1326, in postprocess_data
#     prediction_value = postprocess_update_dict(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 460, in postprocess_update_dict
#     prediction_value["value"] = block.postprocess(prediction_value["value"])
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/gradio_hijack.py", line 326, in postprocess
#     return processing_utils.encode_array_to_base64(y)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py", line 104, in encode_array_to_base64
#     pil_image = Image.fromarray(_convert(image_array, np.uint8, force_copy=False))
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py", line 260, in _convert
#     np.bool8: (False, True),  # type: ignore
#     ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/__init__.py", line 792, in __getattr__
#     raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
# AttributeError: module 'numpy' has no attribute 'bool8'. Did you mean: 'bool'?
# 100% 60/60 [00:57<00:00,  1.04it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-03-16/log.html
# Generating and saving time: 62.39 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.67 seconds
# 100% 60/60 [00:56<00:00,  1.06it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-03-16/log.html
# Generating and saving time: 60.58 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 122.97 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.89 seconds
